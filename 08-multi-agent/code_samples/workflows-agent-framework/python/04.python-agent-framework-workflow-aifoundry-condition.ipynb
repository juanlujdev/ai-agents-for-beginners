# %% [markdown]
# # 🔀 Conditional Agent Workflows with Microsoft Foundry (Python)
#
# ## 📋 Advanced Decision-Based Workflow Tutorial
#
# This notebook demonstrates **conditional workflow patterns** using Microsoft Foundry and the Microsoft Agent Framework. You'll learn how to build intelligent, decision-driven workflows that dynamically route processing based on content analysis, business rules, and AI-powered decision making.
#
# ## 🎯 Learning Objectives
#
# ### 🧠 **Intelligent Decision Making**
# - **Conditional Logic**: Implement dynamic branching based on AI analysis and business rules
# - **Content-Aware Routing**: Route workflow paths based on content analysis and classification
# - **Adaptive Processing**: Adjust workflow behavior based on real-time conditions and data
# - **Azure AI Integration**: Leverage Microsoft Foundry's advanced capabilities for decision making
#
# ### 🔀 **Advanced Workflow Patterns**
# - **Decision Trees**: Build complex decision structures with multiple branching points
# - **Rule-Based Processing**: Implement business logic and compliance requirements
# - **Dynamic Workflow Modification**: Adapt workflows based on runtime conditions
# - **Context-Aware Operations**: Make decisions based on accumulated workflow context
#
# ### 🏢 **Enterprise Conditional Applications**
# - **Document Classification**: Route documents to appropriate processing workflows
# - **Customer Service Triage**: Automatically route inquiries to specialized handling workflows
# - **Compliance Processing**: Apply different validation rules based on content type and regulations
# - **Quality Assurance**: Route content through different review processes based on quality metrics
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Installation & Dependencies**
#
# This workflow requires specific installation steps for Microsoft Foundry integration:
#
# ```bash
#
# pip install agent-framework-azure-ai -U
# ```
#
# ### 🔑 **Microsoft Foundry Configuration**
#
# **Required Azure Resources:**
# - Microsoft Foundry workspace with appropriate models deployed
# - Azure subscription with necessary permissions
# - Azure CLI authentication configured
#
#
# **Authentication Setup:**
# ```bash
# # Azure CLI authentication
# az login
# az account set --subscription "your-subscription-id"
# azd auth login
# ```
#
# ### 🏗️ **Conditional Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Input Document/Request] --> B[Initial Analysis Agent]
#     B --> C{Decision Point}
#     C -->|Condition 1| D[Workflow Path A]
#     C -->|Condition 2| E[Workflow Path B]
#     C -->|Condition 3| F[Workflow Path C]
#     D --> G[Specialized Processing A]
#     E --> H[Specialized Processing B]
#     F --> I[Specialized Processing C]
#     G --> J[Result Integration]
#     H --> J
#     I --> J
#     J --> K[Final Output]
# ```
#
# **Key Components:**
# - **Analysis Agents**: AI agents that evaluate content and make routing decisions
# - **Decision Points**: Conditional logic that determines workflow paths
# - **Specialized Processors**: Different agents optimized for specific content types or scenarios
# - **Integration Layer**: Combines results from different workflow paths
#
# ## 🎨 **Conditional Workflow Design Patterns**
#
# ### 📋 **Document Processing Triage**
# ```
# Document Input → Content Analysis → Classification → Specialized Processing Workflow
# ```
#
# ### 🎯 **Customer Service Routing**
# ```
# Customer Inquiry → Intent Analysis → Urgency Assessment → Route to Specialist Team
# ```
#
# ### 🔍 **Quality Assurance Workflow**
# ```
# Content Input → Quality Metrics → Risk Assessment → Appropriate Review Process
# ```
#
# ### 📊 **Business Intelligence Pipeline**
# ```
# Data Input → Source Analysis → Processing Rules → Specialized Analytics Workflow
# ```
#
# ## 🏢 **Enterprise Benefits**
#
# ### 🎯 **Intelligent Automation**
# - **Smart Routing**: Automatically direct work to the most appropriate processing path
# - **Adaptive Behavior**: Workflows that learn and adapt based on patterns and outcomes
# - **Business Rule Integration**: Incorporate complex business logic and compliance requirements
# - **Context-Aware Processing**: Make decisions based on full workflow context and history
#
# ### 📈 **Operational Efficiency**
# - **Reduced Manual Intervention**: Automated decision making reduces need for human routing
# - **Specialized Processing**: Each workflow path optimized for specific scenarios
# - **Resource Optimization**: Efficient allocation of processing resources based on content type
# - **Faster Time-to-Resolution**: Direct routing to appropriate specialists and processes
#
# ### 🛡️ **Governance & Control**
# - **Audit Trails**: Complete logging of decision points and routing rationale
# - **Compliance Enforcement**: Automatic application of regulatory and policy requirements
# - **Risk Management**: Route high-risk content through enhanced security and review processes
# - **Quality Assurance**: Ensure appropriate level of review based on content characteristics
#
# ### 📊 **Analytics & Optimization**
# - **Decision Analytics**: Track effectiveness of routing decisions and workflow paths
# - **Performance Metrics**: Measure efficiency of different workflow branches
# - **Continuous Improvement**: Identify optimization opportunities in conditional logic
# - **Business Intelligence**: Gain insights into content patterns and processing requirements
#
# Let's build intelligent, decision-driven AI workflows! 🚀

# %%
# %pip install agent-framework-azure-ai -U
# Out:
# Requirement already satisfied: agent-framework-azure-ai in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (1.0.0rc6)
# Requirement already satisfied: agent-framework-core>=1.0.0rc6 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.10.0)
# Requirement already satisfied: agent-framework-openai>=1.0.0rc6 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.10.0)
# Requirement already satisfied: azure-ai-projects<3.0,>=2.0.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (2.3.0)
# Requirement already satisfied: azure-ai-agents<1.2.0b6,>=1.2.0b5 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.2.0b5)
# Requirement already satisfied: azure-ai-inference<1.0.0b10,>=1.0.0b9 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.0.0b9)
# Requirement already satisfied: azure-identity<2,>=1 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.25.3)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (3.14.1)
# Requirement already satisfied: typing-extensions<5,>=4.15.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (4.16.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (2.13.4)
# Requirement already satisfied: python-dotenv<2,>=1 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (1.2.2)
# Requirement already satisfied: opentelemetry-api<2,>=1.39.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (1.43.0)
# Requirement already satisfied: openai<3,>=1.99.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (2.44.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp<4,>=3.7.0->agent-framework-azure-ai) (1.24.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-agents<1.2.0b6,>=1.2.0b5->agent-framework-azure-ai) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-agents<1.2.0b6,>=1.2.0b5->agent-framework-azure-ai) (1.41.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects<3.0,>=2.0.0->agent-framework-azure-ai) (12.30.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-azure-ai) (49.0.0)
# Requirement already satisfied: msal>=1.35.1 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-azure-ai) (1.37.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-agents<1.2.0b6,>=1.2.0b5->agent-framework-azure-ai) (2.34.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-azure-ai) (2.0.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity<2,>=1->agent-framework-azure-ai) (2.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (0.16.0)
# Requirement already satisfied: sniffio in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (4.68.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core>=1.0.0rc6->agent-framework-azure-ai) (0.4.2)
# Requirement already satisfied: idna>=2.0 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.7.0->agent-framework-azure-ai) (3.18)
# Requirement already satisfied: pycparser in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-azure-ai) (3.0)
# Requirement already satisfied: certifi in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents<1.2.0b6,>=1.2.0b5->agent-framework-azure-ai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents<1.2.0b6,>=1.2.0b5->agent-framework-azure-ai) (2.7.0)
# Requirement already satisfied: colorama in c:\users\lujan\proyectos\cursos\ai-agents-for-beginners\.venv\lib\site-packages (from tqdm>4->openai<3,>=1.99.0->agent-framework-openai>=1.0.0rc6->agent-framework-azure-ai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# requirements.txt & constraints.txt - in ./Installation
#
# please copy .env.examples as .env

# %% [markdown]
# **Note** choose gpt-4.1-mini

# %%
import os

from dataclasses import dataclass
from typing_extensions import Literal
from pydantic import BaseModel

# %%
from azure.identity.aio import AzureCliCredential
from dotenv import load_dotenv

from agent_framework import SupportsWebSearchTool 
#from agent_framework import HostedWebSearchTool
#from agent_framework.azure import AzureAIAgentClient
from agent_framework.foundry import FoundryChatClient 
from agent_framework import (
    AgentExecutor,
    AgentExecutorRequest,
    AgentExecutorResponse,
    SupportsCodeInterpreterTool ,
    # ChatMessage,
    Message,
    ChatOptions,
    Role,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowEvent,
    executor,
    WorkflowViz
)


from azure.ai.projects.models import (
    BingGroundingTool,
    BingGroundingSearchToolParameters,
    BingGroundingSearchConfiguration,
    CodeInterpreterTool,
)

# %%
load_dotenv()
# Out:
# True

# %%
EvangelistInstructions = """
You are a technology evangelist create a first draft for a technical tutorials.
1. Each knowledge point in the outline must include a link. Follow the link to access the content related to the knowledge point in the outline. Expand on that content.
2. Each knowledge point must be explained in detail.
3. Rewrite the content according to the entry requirements, including the title, outline, and corresponding content. It is not necessary to follow the outline in full order.
4. The content must be more than 200 words.
4. Output draft as Markdown format. set 'draft_content' to the draft content.
5. return result as JSON with fields 'draft_content' (string).
"""

ContentReviewerInstructions = """
You are a content reviewer for a publishing company. You need to check whether the tutorial's draft content meets the following requirements:

1. The draft content less than 200 words, set 'review_result' to 'No' and 'reason' to 'Content is too short'. If the draft content is more than 200 words, set 'review_result' to 'Yes' and 'reason' to 'The content is good'.
2. set 'draft_content' to the original draft content.
3. return result as JSON with fields 'review_result' (one of Yes, No) and 'reason' (string) and 'draft_content' (string).

"""

PublisherInstructions = """
You are the content publisher ,run code to save the tutorial's draft content as a Markdown file. Saved file's name is marked with current date and time, such as yearmonthdayhourminsec. Note that if it is 1-9, you need to add 0, such as  20240101123045.md. 
"""

# %%
OUTLINE_Content ="""
# Introduce AI Agent


## What's AI Agent

https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents


***Note*** Don's create any sample code 


## Introduce Microsoft Foundry Agent Service 

https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview


***Note*** Don's create any sample code 


## Microsoft Agent Framework 

https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates


***Note*** Don's create any sample code 
"""

# %%
conn_id = os.environ["BING_CONNECTION_ID"]  # Ensure the BING_CONNECTION_NAME environment variable is set

# Initialize the Bing Grounding tool
bing = BingGroundingTool(
    bing_grounding=BingGroundingSearchToolParameters(
        search_configurations=[
            BingGroundingSearchConfiguration(project_connection_id=conn_id)
        ]
    )
)

code_interpreter = CodeInterpreterTool()

# %%
class EvangelistAgent(BaseModel):
    draft_content: str

class ReviewAgent(BaseModel):
    review_result: Literal["Yes", "No"]
    reason: str
    draft_content: str

class PublisherAgent(BaseModel):
    file_path: str

@dataclass
class ReviewResult:
    review_result: str
    reason: str
    draft_content: str

@executor(id="to_reviewer_result")
async def to_reviewer_result(response: AgentExecutorResponse, ctx: WorkflowContext[ReviewResult]) -> None:

    print(f"Raw response from reviewer agent: {response.agent_response.text}")

    parsed = ReviewAgent.model_validate_json(response.agent_response.text)
    await ctx.send_message(
        ReviewResult(
            review_result=parsed.review_result,
            reason=parsed.reason,
            draft_content=parsed.draft_content,
        )
    )


def select_targets(review: ReviewResult, target_ids: list[str]) -> list[str]:
        # Order: [handle_review, save_draft]
        handle_review_id, save_draft_id = target_ids
        if review.review_result == "Yes":
            return [save_draft_id]
        else:
            return [handle_review_id]
        


@executor(id="handle_review")
async def handle_review(review: ReviewResult, ctx: WorkflowContext[str]) -> None:
    if review.review_result == "No":
        await ctx.yield_output(f"Review failed: {review.reason}, please revise the draft.")
    else:
        await ctx.send_message(
            AgentExecutorRequest(messages=[Message(role="user", contents=[review.draft_content])], should_respond=True)
        )
        


@executor(id="save_draft")
async def save_draft(review: ReviewResult, ctx: WorkflowContext[AgentExecutorRequest]) -> None:
    # Forward the approved draft to the publisher agent.
    await ctx.send_message(
        AgentExecutorRequest(messages=[Message(role="user", contents=[review.draft_content])], should_respond=True)
    )

# %%
from IPython.display import SVG, display, HTML

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
import os

# Le indicamos a Python la ruta exacta de Graphviz en Windows
ruta_graphviz = r"C:\Program Files\Graphviz\bin"

if ruta_graphviz not in os.environ["PATH"]:
    os.environ["PATH"] += os.pathsep + ruta_graphviz
    print("¡Ruta de Graphviz añadida con éxito a esta sesión!")
else:
    print("La ruta de Graphviz ya estaba configurada.")
# Out:
# La ruta de Graphviz ya estaba configurada.

# %%
# process_timeout=60: on Windows the az CLI can take longer than the default 10s
# to refresh a token, which raises CredentialUnavailableError mid-workflow.
async with AzureCliCredential(process_timeout=60) as credential:
        chat_client = FoundryChatClient(
            project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
            model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
            credential=credential,
        )
        try:
                evangelist_agent = AgentExecutor(chat_client.as_agent(
                    instructions= (EvangelistInstructions),
                    tools=[chat_client.get_web_search_tool()],
                    # default_options=ChatOptions(response_format=EvangelistAgent)
                ),  id="evangelist_agent")
                reviewer_agent = AgentExecutor(chat_client.as_agent(
                    instructions=(ContentReviewerInstructions),
                    # default_options=ChatOptions(response_format=ReviewAgent)
                ), id="reviewer_agent")
                publisher_agent = AgentExecutor(chat_client.as_agent(
                    instructions=PublisherInstructions,
                    # Plain dict instead of get_code_interpreter_tool(): the SDK helper returns an
                    # AutoCodeInterpreterToolParam that its own telemetry layer cannot JSON-serialize.
                    tools={"type": "code_interpreter", "container": {"type": "auto"}},
                    default_options=ChatOptions(response_format=PublisherAgent)
                ), id="publisher_agent")

                workflow = (
                    WorkflowBuilder(start_executor=evangelist_agent)
                        .add_edge(evangelist_agent, reviewer_agent)
                        .add_edge(reviewer_agent, to_reviewer_result)
                        .add_multi_selection_edge_group(
                            to_reviewer_result,
                            [handle_review, save_draft],
                            selection_func=select_targets,
                        )
                        .add_edge(save_draft, publisher_agent)
                        .build()
                )

                # workflow = SequentialBuilder().participants([evangelist_chat_agent, reviewer_chat_agent, publisher_chat_agent]).build()
                print("Generating workflow visualization...")
                viz = WorkflowViz(workflow)
                # Print out the mermaid string.
                print("Mermaid string: \n=======")
                print(viz.to_mermaid())
                print("=======")
                # Print out the DiGraph string.
                print("DiGraph string: \n=======")
                print(viz.to_digraph())
                print("=======")
                # SVG export needs the optional graphviz extra plus the graphviz system binary;
                # fall back gracefully if it is not available.
                try:
                    svg_file = viz.export(format="svg")
                    print(f"SVG file saved to: {svg_file}")
                except ImportError as e:
                    svg_file = None
                    print(f"SVG export skipped (install graphviz to enable): {e}")

                if svg_file and os.path.exists(svg_file):
                    try:
                        # Preferred: direct SVG rendering
                        display(SVG(filename=svg_file))
                    except Exception as e:
                        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
                        try:
                            with open(svg_file, "r", encoding="utf-8") as f:
                                svg_text = f.read()
                            display(HTML(svg_text))
                        except Exception as inner:
                            print(f"❌ Fallback HTML render also failed: {inner}")
                else:
                    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

                
                task = """
                    You are a evangelist , need to write a  draft based on the following outline and the content provided in the link corresponding to the outline. After draft create , the reviewer check it , if it meets the requirements, it will be submitted to the publisher and save it as a Markdown file, otherwise need to rewrite draft until it meets the requirements.
                        The provided outline content and related links is as follows:

                    """ + OUTLINE_Content

                
                result = await workflow.run(task)
                print("===== Final Workflow Outputs =====")
                for i, output in enumerate(result.get_outputs(), start=1):
                    print(f"{'-' * 60}\n\n{i:02d}:\n{output}")



        finally:
            print("done")
# Out:
# C:\Users\lujan\AppData\Local\Temp\ipykernel_20004\750175972.py:37: DeprecationWarning: WorkflowBuilder built without explicit output_from or intermediate_output_from; every yield_output produces type='output' for compatibility. Pass output_from='all', output_from=[...], or intermediate_output_from=[...] to opt into explicit designation - explicit designation will be required in a future version.
#   .build()
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   evangelist_agent["evangelist_agent (Start)"];
#   reviewer_agent["reviewer_agent"];
#   to_reviewer_result["to_reviewer_result"];
#   handle_review["handle_review"];
#   save_draft["save_draft"];
#   publisher_agent["publisher_agent"];
#   evangelist_agent --> reviewer_agent;
#   reviewer_agent --> to_reviewer_result;
#   to_reviewer_result --> handle_review;
#   to_reviewer_result --> save_draft;
#   save_draft --> publisher_agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "evangelist_agent" [fillcolor=lightgreen, label="evangelist_agent\n(Start)"];
#   "reviewer_agent" [label="reviewer_agent"];
#   "to_reviewer_result" [label="to_reviewer_result"];
#   "handle_review" [label="handle_review"];
#   "save_draft" [label="save_draft"];
#   "publisher_agent" [label="publisher_agent"];
#   "evangelist_agent" -> "reviewer_agent";
#   "reviewer_agent" -> "to_reviewer_result";
#   "to_reviewer_result" -> "handle_review";
#   "to_reviewer_result" -> "save_draft";
#   "save_draft" -> "publisher_agent";
# }
# =======
# SVG file saved to: C:\Users\lujan\AppData\Local\Temp\tmpqg4il8ep.svg
# Raw response from reviewer agent: {
#   "review_result": "Yes",
#   "reason": "The content is good",
#   "draft_content": "# Introduce AI Agent\n\n## Overview\n\nThis draft introduces core concepts for readers who are new to AI agents, and provides a concise orientation to two Microsoft resources that accelerate agent design and delivery: the \"AI Agents for Beginners\" learning repo and the Microsoft Foundry Agent Service, plus the Microsoft Agent Framework documentation templates. Each knowledge point below includes the original link and an expanded explanation that follows the content at the linked source. No sample code is included in this draft (per requirements).\n\n---\n\n## What's an AI Agent\n\nLink: https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents\n\nAt its simplest, an \"AI agent\" is a system that senses its environment, reasons about what it perceives, and takes actions to achieve goals. Modern AI agents—particularly those built around large language models (LLMs)—combine several capabilities: perception (ingesting text, structured data, APIs, or sensor inputs), internal state and memory (which lets the agent remember previous interactions and context), decision-making or planning (selecting high-level strategies and next steps), and action interfaces or tools (APIs, database queries, task orchestration, or other external systems). The community learning repo linked above provides an introductory walkthrough of these ideas and frames the agent as an iterative loop that combines observation, reasoning, and action while applying constraints such as safety, privacy, and cost management.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nKey conceptual points to expand on from the linked material:\n- Agent loop and architecture: The agent repeatedly observes its environment, updates internal state, chooses an action, executes that action through a tool or an API, and then observes the result. Designing a clear loop boundary and well-defined interfaces between perception, reasoning, and action makes the system easier to test and secure.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Memory and context management: Effective agents persist context across turns (short-term working memory and longer-term memory for user preferences or facts). Thoughtful memory policies—what to store, how to index, and how to forget—help keep memory useful and compliant with privacy requirements.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Tooling and capabilities: Treat tools as first-class capabilities (search, database queries, calculator, orchestration). Agents delegate actions to specific tools with explicit interfaces; this isolates risk and improves observability. The repository emphasizes designing safe, well-scoped tools rather than giving the agent unrestricted access.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Safety, guardrails, and prompts: Agents must follow explicit safety policies and have guardrails at both the reasoning and execution layers. This includes prompt design, validation checks before actions, and runtime policy enforcement. The referenced beginner materials frame these as first-class engineering concerns.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nTaken together, the intro materials aim to move a reader from conceptual understanding to a practical mental model for decomposing agent problems—identify goals, enumerate capabilities/tools, design memory and context, and define safety and observability requirements.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\n---\n\n## Introduce Microsoft Foundry Agent Service\n\nLink: https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview\n\nMicrosoft Foundry Agent Service is Microsoft ...
# }
# ===== Final Workflow Outputs =====
# ------------------------------------------------------------
#
# 01:
# {
#   "draft_content": "# Introduce AI Agent\n\n## Overview\n\nThis draft introduces core concepts for readers who are new to AI agents, and provides a concise orientation to two Microsoft resources that accelerate agent design and delivery: the \"AI Agents for Beginners\" learning repo and the Microsoft Foundry Agent Service, plus the Microsoft Agent Framework documentation templates. Each knowledge point below includes the original link and an expanded explanation that follows the content at the linked source. No sample code is included in this draft (per requirements).\n\n---\n\n## What's an AI Agent\n\nLink: https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents\n\nAt its simplest, an \"AI agent\" is a system that senses its environment, reasons about what it perceives, and takes actions to achieve goals. Modern AI agents—particularly those built around large language models (LLMs)—combine several capabilities: perception (ingesting text, structured data, APIs, or sensor inputs), internal state and memory (which lets the agent remember previous interactions and context), decision-making or planning (selecting high-level strategies and next steps), and action interfaces or tools (APIs, database queries, task orchestration, or other external systems). The community learning repo linked above provides an introductory walkthrough of these ideas and frames the agent as an iterative loop that combines observation, reasoning, and action while applying constraints such as safety, privacy, and cost management. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nKey conceptual points to expand on from the linked material:\n- Agent loop and architecture: The agent repeatedly observes its environment, updates internal state, chooses an action, executes that action through a tool or an API, and then observes the result. Designing a clear loop boundary and well-defined interfaces between perception, reasoning, and action makes the system easier to test and secure. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Memory and context management: Effective agents persist context across turns (short-term working memory and longer-term memory for user preferences or facts). Thoughtful memory policies—what to store, how to index, and how to forget—help keep memory useful and compliant with privacy requirements. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Tooling and capabilities: Treat tools as first-class capabilities (search, database queries, calculator, orchestration). Agents delegate actions to specific tools with explicit interfaces; this isolates risk and improves observability. The repository emphasizes designing safe, well-scoped tools rather than giving the agent unrestricted access. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Safety, guardrails, and prompts: Agents must follow explicit safety policies and have guardrails at both the reasoning and execution layers. This includes prompt design, validation checks before actions, and runtime policy enforcement. The referenced beginner materials frame these as first-class engineering concerns. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nTaken together, the intro materials aim to move a reader from conceptual understanding to a practical mental model for decomposing agent problems—identify goals, enumerate capabilities/tools, design memory and context, and define safety and observability requirements. ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\n---\n\n## Introduce Microsoft Foundry Agent Service\n\nLink: https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview\n\nMicrosoft Foundry Agent Service is Microsoft Azure ...
# }
# ------------------------------------------------------------
#
# 02:
# {
#   "review_result": "Yes",
#   "reason": "The content is good",
#   "draft_content": "# Introduce AI Agent\n\n## Overview\n\nThis draft introduces core concepts for readers who are new to AI agents, and provides a concise orientation to two Microsoft resources that accelerate agent design and delivery: the \"AI Agents for Beginners\" learning repo and the Microsoft Foundry Agent Service, plus the Microsoft Agent Framework documentation templates. Each knowledge point below includes the original link and an expanded explanation that follows the content at the linked source. No sample code is included in this draft (per requirements).\n\n---\n\n## What's an AI Agent\n\nLink: https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents\n\nAt its simplest, an \"AI agent\" is a system that senses its environment, reasons about what it perceives, and takes actions to achieve goals. Modern AI agents—particularly those built around large language models (LLMs)—combine several capabilities: perception (ingesting text, structured data, APIs, or sensor inputs), internal state and memory (which lets the agent remember previous interactions and context), decision-making or planning (selecting high-level strategies and next steps), and action interfaces or tools (APIs, database queries, task orchestration, or other external systems). The community learning repo linked above provides an introductory walkthrough of these ideas and frames the agent as an iterative loop that combines observation, reasoning, and action while applying constraints such as safety, privacy, and cost management.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nKey conceptual points to expand on from the linked material:\n- Agent loop and architecture: The agent repeatedly observes its environment, updates internal state, chooses an action, executes that action through a tool or an API, and then observes the result. Designing a clear loop boundary and well-defined interfaces between perception, reasoning, and action makes the system easier to test and secure.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Memory and context management: Effective agents persist context across turns (short-term working memory and longer-term memory for user preferences or facts). Thoughtful memory policies—what to store, how to index, and how to forget—help keep memory useful and compliant with privacy requirements.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Tooling and capabilities: Treat tools as first-class capabilities (search, database queries, calculator, orchestration). Agents delegate actions to specific tools with explicit interfaces; this isolates risk and improves observability. The repository emphasizes designing safe, well-scoped tools rather than giving the agent unrestricted access.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n- Safety, guardrails, and prompts: Agents must follow explicit safety policies and have guardrails at both the reasoning and execution layers. This includes prompt design, validation checks before actions, and runtime policy enforcement. The referenced beginner materials frame these as first-class engineering concerns.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\nTaken together, the intro materials aim to move a reader from conceptual understanding to a practical mental model for decomposing agent problems—identify goals, enumerate capabilities/tools, design memory and context, and define safety and observability requirements.  ([github.com](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents))\n\n---\n\n## Introduce Microsoft Foundry Agent Service\n\nLink: https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview\n\nMicrosoft Foundry Agent Service is Microsoft ...
# }
# ------------------------------------------------------------
#
# 03:
# {"file_path":"/mnt/data/20260718002952.md"}
# done
