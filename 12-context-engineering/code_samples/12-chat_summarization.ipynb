# %% [markdown]
# # Lesson 12 - Chat History Reduction with Agent Scratchpad
#
# This notebook demonstrates how to manage context in long conversations using Microsoft Agent Framework. As conversations grow, the token count increases — eventually exceeding the model's context window. We address this with a **context summarization pattern** and an **agent scratchpad** for persistent memory.
#
# ## What You'll Learn:
# 1. **Why Context Management Matters**: Understanding token limits and context windows
# 2. **Context-Aware Agents**: Building agents that manage their own conversation context
# 3. **Context Summarization Pattern**: Using tools to condense conversation history
# 4. **Agent Scratchpad**: Persistent memory that survives context reduction
#
# ## Prerequisites:
# - Azure OpenAI setup with environment variables configured
# - Understanding of basic agent concepts from previous lessons

# %% [markdown]
# ## Setup

# %%
# %pip install agent-framework azure-ai-projects azure-identity python-dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import asyncio
import dotenv
from datetime import datetime
from pathlib import Path

from agent_framework import tool
from agent_framework.foundry import FoundryChatClient
from azure.identity import DefaultAzureCredential
# Out:
# c:\Users\lujan\Proyectos\Cursos\ai-agents-for-beginners\.venv\Lib\site-packages\agent_framework\_skills.py:122: ExperimentalWarning: [SKILLS] SkillResource is experimental and may change or be removed in future versions without notice.
# c:\Users\lujan\Proyectos\Cursos\ai-agents-for-beginners\.venv\Lib\site-packages\agent_framework\_harness\_file_access.py:602: ExperimentalWarning: [HARNESS] AgentFileStore is experimental and may change or be removed in future versions without notice.

# %%
dotenv.load_dotenv()

endpoint = os.getenv("AZURE_AI_PROJECT_ENDPOINT")
deployment_name = os.getenv("AZURE_AI_MODEL_DEPLOYMENT_NAME")

missing = [k for k, v in {
    "AZURE_AI_PROJECT_ENDPOINT": endpoint,
    "AZURE_AI_MODEL_DEPLOYMENT_NAME": deployment_name
}.items() if not v]

if missing:
    raise ValueError(
        f"Missing required environment variables: {', '.join(missing)}. "
        "Please set them as environment variables (e.g., in your .env file or shell environment)."
    )

# Create the Microsoft Foundry client
client = FoundryChatClient(
    project_endpoint=endpoint,
    model=deployment_name,
    credential=DefaultAzureCredential()
)

print("Microsoft Foundry client configured")
# Out:
# Microsoft Foundry client configured

# %% [markdown]
# ## Why Context Management Matters
#
# Every LLM has a finite **context window** — the maximum number of tokens it can process in a single request. As a multi-turn conversation progresses:
#
# - **Token count grows linearly** with each user message and assistant reply.
# - **Prompt tokens dominate cost** because the entire history is re-sent every turn.
# - Eventually the conversation **exceeds the context window** and the model either truncates or errors.
#
# ### Strategies for Managing Context
#
# | Strategy | How It Works | Trade-off |
# |---|---|---|
# | **Truncation** | Drop oldest messages | Loses early context |
# | **Summarization** | Condense older messages into a summary | Some detail lost, but key points retained |
# | **Scratchpad / External Memory** | Store key facts outside the conversation | Requires tool calls, but survives any reduction |
#
# In this notebook we combine **summarization** with a **scratchpad tool** so the agent can maintain continuity even when conversation history is condensed.

# %% [markdown]
# ## Creating a Context-Aware Agent

# %%
agent = client.as_agent(
    name="ContextAwareAgent",
    instructions="""You are a helpful travel planning assistant with excellent memory management.
When conversations get long:
1. Summarize previous context into key points
2. Track user preferences mentioned earlier
3. Reference previous decisions without repeating full details
Always maintain continuity while being concise.""",
)

print("Context-aware travel planning agent created")
# Out:
# Context-aware travel planning agent created

# %% [markdown]
# ## Simulating a Long Conversation
#
# Let's walk through a multi-turn conversation to see how context accumulates. The agent should retain key details (preferences, budget, travel dates) across turns and demonstrate continuity.

# %%
session = agent.create_session()

# Turn 1 - Initial preferences
response = await agent.run("I'm planning a trip to Japan. I love sushi, temples, and photography.", session=session)
print(f"Turn 1: {response}\n")

# Turn 2 - More details
response = await agent.run("My budget is $3000 and I'll be traveling solo for 10 days in April.", session=session)
print(f"Turn 2: {response}\n")

# Turn 3 - Test context retention
response = await agent.run("Based on everything I've told you so far, what's the one thing you'd recommend I not miss?", session=session)
print(f"Turn 3: {response}\n")
# Out:
# Turn 1: Great — thanks, that helps. I’ve noted your top interests: sushi, temples, and photography. A few quick questions so I can build a trip that fits you:
#
# 1. When are you going (dates or season)?
# 2. How long will your trip be?
# 3. Arrival / departure city (Tokyo, Osaka, etc.) or flexible?
# 4. Travel style & budget (low, midrange, comfort/luxury)? Solo or with others?
# 5. Any mobility limits or dietary restrictions?
# 6. Do you want guided tours/workshops (e.g., sushi-making, photo tour)?
# 7. Will you be traveling long distances (want JR Pass advice)?
# 8. What kind of photography do you prefer most (landscape, street, night, architecture, portraits)? Do you bring tripod?
#
# Below is a ready-to-customize sample 10-day itinerary focused on sushi, temples, and photo opportunities. I can shorten/lengthen or reroute once you answer the questions.
#
# Sample 10-day Japan trip (sushi + temples + photography)
# Day 1 — Tokyo arrival
# - Settle in; evening stroll in Shinjuku/Golden Gai for street/night photography.
#
# Day 2 — Tokyo: Tsukiji/Toyosu + Asakusa
# - Morning: Toyosu fish market viewing; sushi brunch at a nearby counter (reserve if possible).
# - Afternoon: Senso-ji Temple (Asakusa) — great for temple architecture and street photos on Nakamise-dori.
# - Evening: Sumida River or Tokyo Skytree viewpoint for skyline shots.
#
# Day 3 — Tokyo: Shibuya/Shinjuku/Meiji
# - Morning: Meiji Shrine and Yoyogi Park (forest feel and shrine architecture).
# - Afternoon: Shibuya Crossing, Harajuku street photography.
# - Optional evening omakase reservation in Ginza.
#
# Day 4 — Kamakura day trip (1 hour from Tokyo)
# - Tsurugaoka Hachimangu, Kotoku-in (Great Buddha), Hasedera temple — coastal temple scenes and quieter streets.
#
# Day 5 — Travel to Kyoto (Shinkansen) — check JR Pass suitability
# - Afternoon: Gion walk, Yasaka Shrine — golden-hour photos and possible geisha sightings.
# - Evening: Dinner at a local sushi restaurant.
#
# Day 6 — Kyoto: Eastern temples + Fushimi Inari
# - Early morning: Fushimi Inari (best at sunrise for photos).
# - Late morning/afternoon: Kiyomizu-dera, Sannen-zaka/Ninen-zaka streets.
# - Sunset: Kiyomizu or Higashiyama viewpoints.
#
# Day 7 — Kyoto: Arashiyama + Golden Pavilion
# - Early: Arashiyama Bamboo Grove (arrive very early to avoid crowds).
# - Ryoan-ji and Kinkaku-ji (Golden Pavilion) — temple gardens and reflective shots.
#
# Day 8 — Nara or Hiroshima option
# - Nara: Todai-ji (Great Buddha), Nara Park with deer (closer, easier).
# - OR Hiroshima + Miyajima (famous Itsukushima torii — spectacular photography at high/low tide; requires overnight if far).
#
# Day 9 — Osaka (food & night photography)
# - Dotonbori for neon/night street photography and excellent sushi/takoyaki. Try an izakaya or sushi-ya.
# - Optional: Kuromon Market for fresh seafood and photo ops.
#
# Day 10 — Departure from Osaka/Tokyo
# - Last-minute shopping, a final sushi meal, depart.
#
# Practical tips and notes
# - Sushi: reserve omakase counters in Ginza/Tokyo and Kyoto weeks to months ahead for top places. Affordable sushi counters and markets (Toyosu/Tsukiji Outer Market, Kuromon) are excellent alternatives.
# - Temples: arrive at sunrise or late afternoon to avoid crowds and get soft light for photos. Some temples restrict tripods — check onsite rules. Dress respectfully; remove hats in some areas.
# - Transport: consider a JR Pass if you’ll use Shinkansen multiple times (cost-effective for ~3+ long journeys). Buy an IC card (Suica/Pasmo/ICOCA) for local travel.
# - Reservations & gear: book omakase, popular photo tours, or workshops early. Bring extra batteries and an ND/UV/filter set if you shoot landscapes/long exposures. A lightweight tripod is useful but be aware of restrictions.
# - Connectivity & cash: get pocket Wi‑Fi or SIM; many small vendors accept cash only.
#
# If you tell me your dates, trip length, arrival city, and budget/style, I’ll draft a tailored day-by-day plan with suggested restaurants, specific temples and photo spots, and transit details (including whether a JR Pass makes sense). Would you like that?
#
# Turn 2: Summary
# - Interests: sushi, temples, photography.
# - Trip: solo, 10 days in April.
# - Budget: $3,000 (please tell me if that includes international airfare).
#
# Before I draft a fully detailed day-by-day with reservations and transit times, two quick clarifying questions:
# 1. Does the $3,000 budget include your international flights?
# 2. Do you prefer starting in Tokyo or Osaka (or are you flexible)?
# Also tell me: hotel style (budget / midrange / comfort), and whether you want 1–2 splurge omakase dinners or none.
#
# Recommended plan overview (best for sushi + temples + photo ops in April)
# - Start in Tokyo (4 nights) → day trip to Kamakura → Shinkansen to Kyoto (4 nights) → day trip to Nara → finish in Osaka (1 night) or return to Tokyo depending on flights. April = cherry‑blossom season: expect crowds and book early.
#
# 10-day sample itinerary (concise)
# Day 1 — Tokyo arrival
# - Settle, golden-hour street/night shots in Shinjuku or Shibuya.
#
# Day 2 — Toyosu/Tsukiji + Asakusa
# - Morning: Toyosu observation & outer market or Tsukiji stalls; sushi brunch at a standing counter (great photo and flavor).
# - Afternoon: Senso‑ji (Asakusa), Nakamise-dori street photography. Evening skyline photos at Sumida River/Skytree.
#
# Day 3 — Meiji Shrine + Harajuku + Ginza
# - Morning: Meiji Shrine (forest/shrine architecture).
# - Afternoon: Harajuku for street portraits, Shibuya Crossing for long-exposure/night shots.
# - Evening: Ginza omakase reservation (if splurging).
#
# Day 4 — Kamakura day trip
# - Tsurugaoka Hachimangu, Kotoku‑in (Great Buddha), Hasedera — coastal temple & quiet streets for photos.
#
# Day 5 — Shinkansen to Kyoto
# - Afternoon: Gion at golden hour, Yasaka Shrine; wander Pontocho and consider a sushi dinner.
#
# Day 6 — Fushimi Inari + Kiyomizu-dera
# - Sunrise at Fushimi Inari (best for photos), late morning Kiyomizu-dera and historic lanes Sannen/Zaka.
#
# Day 7 — Arashiyama + Kinkaku-ji
# - Early bamboo grove, Tenryu‑ji garden, Ryoan‑ji, Kinkaku‑ji (Golden Pavilion reflections at good light).
#
# Day 8 — Philosopher’s Path + Nishiki Market
# - Morning: Philosopher’s Path (cherry blossoms possible), silver pavilion (Ginkaku‑ji).
# - Afternoon: Nishiki Market for food photography and casual sushi options; evening free.
#
# Day 9 — Nara day trip or Miyajima (Hiroshima)
# - Nara: Todai‑ji, deer park (easier).
# - OR Miyajima: Itsukushima torii — spectacular if you want a longer travel day.
#
# Day 10 — Osaka or Tokyo departure
# - Osaka: Dotonbori/Kuromon Market for night neon & food photos; last sushi meal; depart.
#
# Budget guidance and approximate breakdown (USD, for 10 days, excluding or including flights—confirm)
# - Accommodation (midrange business hotels / 3-star / ryokan mix): $70–140/night → $700–1,400.
# - Food: $30–60/day casual; include 1–2 omakase splurges ($80–200 each) → $400–700.
# - Transport: Tokyo↔Kyoto Shinkansen one-way ≈ $100–150; roundtrip ≈ $200–300. Local transit + IC card ≈ $50–120. JR Pass likely not necessary unless you add more long-distance legs.
# - Activities, entrances, tours (photo tour, sushi class): $100–300.
# - SIM/pocket Wi‑Fi and miscellaneous: $50–150.
#
# Estimated total (without international airfare): $1,500–2,500 depending on lodging and number of splurges. If international flights are included in your $3,000, you’ll want to lean mid/low-range lodging and 1 splurge omakase; if flights are extra, you have more flexibility.
#
# Photography and temple tips
# - Cherry blossoms: peak varies by location; early April is generally great in Kyoto/Tokyo — book lodging early.
# - Sunrise & golden hour: best for popular temples (Fushimi Inari, Arashiyama, Kiyomizu).
# - Tripods: often restricted at busy temples and markets — bring a lightweight tripod but be prepared to handhold. Fast primes (f/1.8–2.8) help in low light. Extra batteries, rain cover, and ND filters are useful.
# - Respectful shooting: avoid photographing inside private shrine areas or where signs prohibit it; be mindful of monks/priests and worshippers.
#
# Money & reservations
# - Book omakase and popular restaurants 3–8 weeks ahead for April; book hotels ASAP for hanami season.
# - Use Suica/Pasmo/ICOCA for city travel. Carry some cash — small vendors may be cash-only.
#
# Next steps
# - Tell me whether your $3,000 includes flights and which city you prefer to arrive in. Also pick accommodation level (budget / midrange / comfort) and how many omakase splurges you want. I’ll then:
#   - Produce a detailed day-by-day plan with specific restaurant recommendations, reservation links (where possible), and train times/costs; and
#   - Give a final budget estimate that matches your constraints.
#
# Would you like me to proceed with Tokyo first (recommended) or start in Osaka?
#
# Turn 3: Quick recap
# - Interests: sushi, temples, photography.
# - Trip: solo, 10 days in April, $3,000 budget.
#
# One thing not to miss
# - Sunrise at Fushimi Inari Taisha (the torii tunnel in Kyoto).
#
# Why
# - It’s a uniquely photogenic temple experience: thousands of vermilion torii create dramatic lines and patterns ideal for both wide-angle and intimate compositions, and early-morning light + low crowds make for unforgettable photos and atmosphere.
#
# Practical tips
# - When: arrive ~30–45 minutes before sunrise to walk the lower gates and reach quieter sections as light improves. April can still be busy later in the morning.
# - Getting there: 2–5 minute walk from Inari Station (JR Nara Line) or a short trip from Kyoto Station.
# - Gear: wide-angle (16–35mm or equivalent) and a fast prime for low light; a small tripod is helpful for long exposures but be discreet and avoid blocking paths. Extra batteries and an ND for creative long exposures.
# - Time to allow: 1.5–3 hours (you can hike up the mountain path for different vantage points).
# - Respect: stay to the side of walkways, follow signage, and be quiet—this is a living shrine.
#
# If you want, I can build a sunrise plan that pairs Fushimi Inari with nearby photo/food stops (e.g., early sushi/brunch in Gion or Nishiki Market) and pick exact train times. Would you like that?

# %% [markdown]
# Notice how the agent retains context from earlier turns — it knows about Japan, sushi, temples, photography, the $3000 budget, solo travel, and the April timeframe. In a short conversation this works well, but as the conversation grows the full history becomes expensive to re-send.
#
# Let's continue the conversation with more turns to see context accumulation:

# %%
# Turn 4 - Expand the conversation
response = await agent.run("What about accommodation? I prefer traditional Japanese inns.", session=session)
print(f"Turn 4: {response}\n")

# Turn 5 - Change of plans
response = await agent.run("Actually, I've changed my mind about the dates. I'll go in October instead for the autumn colors.", session=session)
print(f"Turn 5: {response}\n")

# Turn 6 - Test retention after change
response = await agent.run("Summarize my complete travel plan so far — destination, budget, duration, interests, accommodation, and timing.", session=session)
print(f"Turn 6: {response}\n")
# Out:
# Turn 4: Nice — I’ve noted you prefer traditional Japanese inns (ryokan). Here’s a compact plan and practical guidance to fit your solo 10‑day April trip and $3,000 budget.
#
# Quick accommodation strategy (recommended)
# - Mix tradition + practicality: 2–3 nights in a Kyoto ryokan (core “Japanese inn” experience), 1 night in an onsen town (Arima Onsen near Kyoto or Hakone near Tokyo), and the rest in smaller ryokan/guesthouses or machiya rentals in Tokyo and Osaka to keep costs reasonable and allow easy transit.
# - Why: full kaiseki + tatami stays are memorable but pricier — mixing keeps you in-budget while still getting authentic nights.
#
# Suggested nightly allocation (example)
# - Tokyo (Asakusa/Yanaka): 2 nights — small ryokan/guesthouse (~$70–140/night)
# - Kyoto (Gion/Higashiyama/Arashiyama): 3 nights — midrange ryokan or machiya (~$150–300/night)
# - Arima Onsen (or Hakone): 1 night — onsen ryokan (~$150–300/night, often includes dinner & breakfast)
# - Kyoto/nearby or Osaka (machiya/ryokan-style guesthouse): 3 nights — mix of budget ryokan and comfortable guesthouse (~$80–160/night)
#
# Estimated cost impact
# - Midrange ryokan nights with dinner can run $150–350 per person/night. Budget ryokan/guesthouses $50–120.
# - If you do 4 nights in true ryokan (with dinner) and 6 nights in mid/budget places, expect accommodation ~$900–1,600 of your total trip cost — affordable within your $3,000 if you limit 1–2 splurge meals and choose midrange elsewhere.
#
# Where to stay (neighborhoods + examples)
# - Tokyo
#   - Asakusa or Yanaka: Traditional-feel and small ryokan/guesthouses, close to temples and good for photography. Example: Sawanoya Ryokan (Yanaka) — family run, budget friendly.
# - Kyoto
#   - Gion / Higashiyama: Stay in a machiya (traditional townhouse) or a ryokan to be within walking distance of temple photo spots and evening Gion atmosphere. Examples: Ryokan Yachiyo (midrange), Arashiyama Benkei (if you want river views in Arashiyama). For a splurge: Hoshinoya Kyoto.
# - Onsen night (optional)
#   - Arima Onsen (near Kobe, easily reached from Kyoto): classic onsen town, great if you want a relaxing single-night onsen experience without detouring far.
#   - Hakone (if you prefer to do onsen while still in the Tokyo leg): many ryokan with hot-spring baths and views of Mt. Fuji (weather permitting).
# - Osaka
#   - Central or Dotonbori area: ryokan-style guesthouses or small boutique inns; Osaka has fewer classic ryokan but good machiya-style stays.
#
# Booking tips & services
# - Book as early as possible for April (cherry blossom season). Ryokan fill up fast.
# - Use Rakuten Travel, Jalan, Japanican, Booking.com or the ryokan’s direct site. Some ryokan only accept email/phone reservations or require prepayment.
# - Request single occupancy pricing up front (many ryokan quote per person with a 2-person minimum for kaiseki). Some will accept solo guests but charge similar rates — clarify before booking.
#
# Ryokan etiquette (concise essentials)
# - Remove shoes at the entrance; wear slippers (not on tatami).
# - Rooms have tatami and futon — staff may set futon after dinner.
# - Onsen rules: wash fully before entering; no swimsuits; long hair tied up; tattoos may be restricted (ask ahead).
# - Meals: kaiseki dinners often included — they are part of the experience and typically served at set times. Inform ryokan of dietary restrictions in advance.
# - Quiet, respectful behavior is expected; tipping is not customary.
#
# Practical tips for photographers and solo travelers
# - Ask for a room with a view if you want early-morning temple/river/city views.
# - If you plan long-distance travel with luggage, use takuhaibin (luggage forwarding) to send large bags between hotels — ryokan staff handle it well.
# - Confirm check-in times (many ryokan expect arrivals before ~8–9pm) and any dinner cut-off times.
#
# Would you like me to:
# - 1) Draft a concrete 10‑day accommodation plan (specific ryokan names, exact nights, and estimated prices) that fits the $3,000 budget; or
# - 2) Search for current availability and make bookings (I’ll need confirmation whether your $3,000 includes international flights)?
#
# Which would you prefer?
#
# Turn 5: Summary / what I’ve remembered
# - Interests: sushi, temples, photography.
# - Trip: solo, 10 days, $3,000 budget.
# - Accommodation preference: traditional ryokan stays.
# - You’ve changed dates from April to October (autumn colors).
#
# Key implications of switching to October
# - Upside: cooler, comfortable weather and beautiful autumn color (koyo) beginning at higher elevations and in northern regions — great for temple & landscape photography. Fewer crowds than April cherry-blossom peaks in many places.
# - Timing: peak koyo in Kyoto/Tokyo is usually mid–late November, not October. To reliably see strong autumn color in October you’ll want higher elevations or more northern areas (Nikko, the Japanese Alps, and parts of Tohoku/Hokkaido) or specific spots that turn earlier.
#
# Where you’ll most likely see vivid colors in October (good for temples + photos)
# - Nikko (Tochigi) — Toshogu Shrine and Lake Chuzenji area: often excellent late Oct → early Nov. Easy 2-hour trip from Tokyo.
# - Higher-elevation spots (Japanese Alps, Kamikochi) — strong color in mid–Oct at altitude. More travel/time required.
# - Tohoku / Hirosaki / Bandai‑Azuma region — early–mid Oct peak (requires domestic flights / longer travel).
# - Kyoto & Arashiyama — usually peak mid–late Nov; in October you’ll see some color but not full koyo. Still excellent for temples and photography, especially with ryokan ambiance.
#
# Practical changes I recommend
# - Option A (balanced, minimal extra travel): Keep Tokyo → Kyoto → Nara → Osaka route but add a day trip to Nikko from Tokyo early in the trip to get earlier colors. Spend 2–3 nights in Kyoto as planned (you’ll still get good shots even if not peak). Include one onsen ryokan night (Arima near Kyoto or Hakone from Tokyo) for autumn foliage + hot springs.
# - Option B (koyo‑focused): Tokyo → Nikko (1–2 nights) → travel to the Japanese Alps (Takayama / Kamikochi) or head north (Tohoku) for the heart of October colors — more travel/time but much stronger autumn color. Requires adjusting transport and possibly a domestic flight or extra shinkansen rides.
# - Keep your ryokan preference: book ASAP. Autumn is popular for koyo weeks and ryokan fill up early.
#
# Photography tips for October koyo
# - Polarizing filter to boost leaf color and reduce reflections.
# - Telephoto (70–200mm) for compressed color details; wide angle (16–35mm) for temple + landscape combos.
# - Tripod + remote for low-light forest scenes and long exposures (mornings can be misty). Many temples allow tripods outside main halls but check local rules.
# - Shoot early morning for mist/golden light and fewer people; afternoons give warm side-light for leaves.
# - Watch weather/typhoon forecasts (October has lower typhoon frequency than September but still possible).
#
# Ryokan & booking notes for October
# - Book ryokan immediately for October, especially if you want to stay in Kyoto (Gion/Arashiyama) or in popular onsen towns during koyo season. Expect slightly higher rates for prime koyo weeks.
# - If you want, I can propose a specific 10‑day October itinerary with exact ryokan recommendations and estimated pricing that fits your $3,000 budget.
#
# Quick questions to finalize a revised plan
# 1. Does the $3,000 include international flights?
# 2. Do you prefer to prioritize seeing the strongest autumn colors even if it means more travel (Option B), or keep the original Tokyo→Kyoto route with a Nikko add-on (Option A)?
# 3. Which city will you fly into/out of (Tokyo or Osaka), or are you flexible?
#
# Tell me which option you prefer (A or B) and answer the quick questions above and I’ll draft a detailed October itinerary with ryokan picks and updated budget.
#
# Turn 6: Here’s a concise summary of your travel plan so far.
#
# - Destination: Japan — main focus on Tokyo and Kyoto with day trips (Kamakura, Nara/Osaka). Potential additions for autumn color: Nikko or higher-elevation/Japanese Alps / Tohoku if you choose a koyo-focused route.
# - Budget: $3,000 total (you have not yet confirmed whether this includes international airfare).
# - Duration: 10 days, solo.
# - Interests: Sushi, temples, and photography. (Top single recommendation: sunrise at Fushimi Inari Taisha.)
# - Accommodation preference: Traditional Japanese inns (ryokan). Plan is to mix ryokan stays — 2–3 nights in Kyoto ryokan, 1 onsen night (Arima or Hakone), and ryokan/guesthouse or machiya-style stays in Tokyo/Osaka to stay within budget.
# - Timing: October (you changed from April to October to pursue autumn colors). Notes: peak koyo in Kyoto is usually mid–late November — for strong October colors consider Nikko, the Japanese Alps, or Tohoku. Book ryokan early for koyo season.
#
# Outstanding decisions I need from you to finalize bookings and a day-by-day plan
# 1) Does the $3,000 include international flights?
# 2) Do you prefer Option A (keep Tokyo→Kyoto→Nara→Osaka + add Nikko day trip) or Option B (rework route to prioritize stronger October koyo in Nikko/Japanese Alps/Tohoku)?
# 3) Preferred arrival/departure city (Tokyo or Osaka), or flexible?
#
# Tell me those and I’ll draft a detailed 10‑day October itinerary with specific ryokan recommendations and an updated budget.

# %% [markdown]
# ## Context Summarization Pattern
#
# As the conversation grows, we can use a **summarization tool** to condense accumulated context into a compact format. The agent calls this tool to record key preferences so that even if older messages are dropped, the essential information is preserved.
#
# This pattern is the building block for more sophisticated history reduction:
# 1. The agent identifies key facts from the conversation
# 2. It calls the summarization tool to persist them
# 3. Older messages can be safely removed because the summary captures what matters
#
# Below we define a `summarize_preferences` tool that the agent can call to record a compact summary of what it has learned.

# %%
@tool(approval_mode="never_require")
def summarize_preferences(conversation_notes: str) -> str:
    """Summarize accumulated user preferences into a compact format."""
    return f"[SUMMARY] User preferences recorded: {conversation_notes}"


# Create an enhanced agent with the summarization tool
summarizing_agent = client.as_agent(
    name="SummarizingTravelAgent",
    instructions="""You are a helpful travel planning assistant that actively manages conversation context.

CONTEXT MANAGEMENT RULES:
1. After gathering several user preferences, call summarize_preferences() to record a compact summary
2. When the user asks you to recall details, reference your recorded summaries
3. Keep responses concise — avoid restating the entire history

PLANNING PROCESS:
1. Gather user preferences (destination, budget, dates, interests)
2. Summarize preferences using the tool
3. Create recommendations based on the summary
4. Update the summary when preferences change""",
    tools=[summarize_preferences],
)

print("Summarizing travel agent created with context tools")
# Out:
# Summarizing travel agent created with context tools

# %%
# Demonstrate the summarization pattern
summary_session = summarizing_agent.create_session()

# Provide a batch of preferences
response = await summarizing_agent.run(
    "I want to visit Greece. I love seafood, history, and island hopping. "
    "Budget is $4000 for two weeks. Traveling with my partner in June. "
    "Please record these preferences using your summarization tool.",
    session=summary_session,
)
print(f"Agent: {response}\n")

# Ask the agent to use the recorded context
response = await summarizing_agent.run(
    "Now, based on what you've recorded, suggest the top 3 islands we should visit.",
    session=summary_session,
)
print(f"Agent: {response}\n")
# Out:
# Agent: Preferences saved.
#
# Quick plan (concise):
# - Sample route (14 days): Athens (2 nights: Acropolis, Plaka) → Saronic island hop to Hydra or Aegina (1–2 nights) → Ferry to Naxos or Paros (4 nights: beaches, local seafood, ancient sites) → Milos (2 nights: unique coastlines, seafood) → Santorini (2–3 nights: archaeology at Akrotiri, sunset views). Return to Athens day before departure.
# - Why this works: mixes mainland history (Athens), easy short hops (Saronic + Cyclades), and islands known for seafood and varied scenery. June is ideal for good weather and active ferry schedules.
# - Budget check (approx, for two people, excluding long-haul international flights unless you say otherwise):
#   - Inter-island ferries and one fast ferry: $300–500
#   - Accommodation (mid-range): $1,400–1,800 (14 nights)
#   - Food & drink (seafood-focused dining): $700–900
#   - Local transport, site fees, extras: $300–500
#   - Buffer/activities (boat trip, archaeology tours): $200–400
#   - Total estimate: ~$2,900–4,100
#   Given $4,000, you can do mid-range travel; adjust islands (skip Santorini or shorten stay) to reduce cost.
# - Next choices for me to act on (pick any):
#   1) Build a day-by-day itinerary with specific ferries and suggested hotels (I’ll include estimated costs).
#   2) Optimize route to lower costs (cheaper islands, slower ferries).
#   3) Ask about departure city / whether budget should include international flights.
#   4) Start booking assistance (I can outline steps; I cannot book directly).
#
# Which would you like next?
#
# Agent: Recorded preferences: Greece, June, 2 weeks, $4,000 for two, interests = seafood, history, island hopping.
#
# Top 3 islands I recommend:
# 1. Naxos
#    - Why: Strong combo of ancient sites (Portara, Temple of Demeter), excellent local seafood and farm-to-table produce, great beaches and lots of island-hopping connections. Budget-friendly.
#    - Logistics: Frequent ferries from Piraeus; short hops to Paros.
#
# 2. Milos
#    - Why: Dramatic, varied coastline and boat trips (Kleftiko) with superb seafood by the water; quieter and highly photogenic. Great for coastal exploration and seafood-focused meals.
#    - Logistics: Direct ferries from Piraeus or via Paros; good for 1–3 nights.
#
# 3. Paros
#    - Why: Charming villages (Naoussa, Parikia), lively tavernas/seafood scene, very convenient hub for island-hopping (fast ferries to Naxos, Mykonos, Milos).
#    - Logistics: Central in the Cyclades—easy transfers and flexible for changing plans.
#
# Quick note: If you want an iconic archaeological highlight and sunset views, swap Paros for Santorini (Akrotiri + dramatic caldera) — but Santorini is pricier and more crowded.
#
# Want me to build a 14-day route using Naxos–Milos–Paros (with Athens start/end) and show ferry times and estimated costs?

# %% [markdown]
# ## Summary
#
# In this lesson you learned how to manage context in long-running agent conversations using Microsoft Agent Framework:
#
# ### Key Concepts
# - **Context windows are finite** — every token in the conversation history costs money and counts toward the limit.
# - **Summarization tools** let the agent condense accumulated context into compact summaries, reducing token usage while preserving essential information.
# - **Agent scratchpads** provide persistent external memory that survives any conversation reduction.
#
# ### What You Built
# - A **context-aware agent** that maintains continuity across multi-turn conversations
# - A **summarization tool** (`summarize_preferences`) that records key user details in a compact format
# - A **multi-turn conversation** demonstrating context retention and change handling
#
# ### Real-World Applications
# - **Customer Service Bots**: Remember preferences across long support sessions
# - **Personal Assistants**: Track ongoing projects without re-explaining context
# - **Educational Tutors**: Maintain student progress across many interactions
#
# ### Next Steps
# - Implement a full scratchpad tool with file-based persistence
# - Add automatic history truncation after summarization
# - Combine with vector databases for semantic memory search
# - Build agents that can resume conversations days later with full context
